# %% [markdown]
# <a href="https://colab.research.google.com/github/imranttsia/Deep-learning/blob/main/IMBD_Deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3.4.1 The IMDB dataset

# %% [markdown]
# 1)Samples 50,000 review samples
# 2)25,000 for training and 25,000 for testing
# 3)50% Negative and 50% positive Reviews
# 4)Available in Kears pre data sets
# 5)pre converted in Vector numbers where each number replace specific word :)
# 6)80 Mb data size download when you first run otherwise you can see this data set file in .keras folder

# %% [markdown]
# Listing 3.1 Loading the IMDB dataset

# %%
from tensorflow.keras.datasets import imdb
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)
# Out:
# ...
# 17464789/17464789 [==============================] - 0s 0us/step

# %% [markdown]
# The argument num_words=10000 means you’ll only keep the top 10,000 most frequently occurring words in the training data.

# %% [markdown]
#  0------    1----   2------     3------     4-  5-------     6
#
# [We love our country. I am Pakistani]

# %% [markdown]
# Encode Message
#
# [013] [We love country] (len=3)
#
# [56321] [am Pakistani country our love] (len=5)
#
# OneHotEncode
#
# [013] = [1,1,0,1,0,0,0] (len=7)
#
# [56321] = [0,1,1,1,0,1,1] (len=7)

# %%
print("X:\n",train_data[0])
print("Y:\n",train_labels[0])
# Out:
# X:
#  [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]
# Y:
#  1

# %%
print(len(train_data[0]))
print(len(train_data[1]))
# Out:
# 218
# 189

# %% [markdown]
# Because you’re restricting yourself to the top 10,000 most frequent words, no word index will exceed 10,000:

# %%
max([max(sequence) for sequence in train_data])
# Out:
# 9999

# %%
word_index = imdb.get_word_index()

reverse_word_index = dict(
    [(value, key) for (key, value) in word_index.items()])


decoded_review = ' '.join(
    [reverse_word_index.get(i - 3, '?') for i in train_data[0]])

# %%
decoded_review
# Out:
# "? this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert ? is an amazing actor and now the same being director ? father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for ? and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also ? to the two little boy's that played the ? of norman and paul they were just brilliant children are often left out of the ? list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you 
# ...

# %%
word_index
# Out:
# {'fawn': 34701,
#  'tsukino': 52006,
#  'nunnery': 52007,
#  'sonja': 16816,
#  'vani': 63951,
#  'woods': 1408,
#  'spiders': 16115,
#  'hanging': 2345,
#  'woody': 2289,
#  'trawling': 52008,
#  "hold's": 52009,
#  'comically': 11307,
#  'localized': 40830,
#  'disobeying': 30568,
#  "'royale": 52010,
#  "harpo's": 40831,
#  'canet': 52011,
#  'aileen': 19313,
#  'acurately': 52012,
#  "diplomat's": 52013,
#  'rickman': 25242,
#  'arranged': 6746,
#  'rumbustious': 52014,
#  'familiarness': 52015,
#  "spider'": 52016,
#  'hahahah': 68804,
#  "wood'": 52017,
#  'transvestism': 40833,
#  "hangin'": 34702,
#  'bringing': 2338,
#  'seamier': 40834,
#  'wooded': 34703,
#  'bravora': 52018,
#  'grueling': 16817,
#  'wooden': 1636,
#  'wednesday': 16818,
#  "'prix": 52019,
#  'altagracia': 34704,
#  'circuitry': 52020,
#  'crotch': 11585,
#  'busybody': 57766,
#  "tart'n'tangy": 52021,
#  'burgade': 14129,
#  'thrace': 52023,
#  "tom's": 11038,
#  'snuggles': 52025,
# ...

# %%
reverse_word_index
# Out:
# {34701: 'fawn',
#  52006: 'tsukino',
#  52007: 'nunnery',
#  16816: 'sonja',
#  63951: 'vani',
#  1408: 'woods',
#  16115: 'spiders',
#  2345: 'hanging',
#  2289: 'woody',
#  52008: 'trawling',
#  52009: "hold's",
#  11307: 'comically',
#  40830: 'localized',
#  30568: 'disobeying',
#  52010: "'royale",
#  40831: "harpo's",
#  52011: 'canet',
#  19313: 'aileen',
#  52012: 'acurately',
#  52013: "diplomat's",
#  25242: 'rickman',
#  6746: 'arranged',
#  52014: 'rumbustious',
#  52015: 'familiarness',
#  52016: "spider'",
#  68804: 'hahahah',
#  52017: "wood'",
#  40833: 'transvestism',
#  34702: "hangin'",
#  2338: 'bringing',
#  40834: 'seamier',
#  34703: 'wooded',
#  52018: 'bravora',
#  16817: 'grueling',
#  1636: 'wooden',
#  16818: 'wednesday',
#  52019: "'prix",
#  34704: 'altagracia',
#  52020: 'circuitry',
#  11585: 'crotch',
#  57766: 'busybody',
#  52021: "tart'n'tangy",
#  14129: 'burgade',
#  52023: 'thrace',
#  11038: "tom's",
#  52025: 'snuggles',
# ...

# %%
print(train_labels[0])
decoded_review
# Out:
# 1
# ...

# %% [markdown]
# 3.4.2 Preparing the data

# %% [markdown]
# 1- each sample length are differents but our network accept specific shape size tensor
#
# 2- we have to convert each sample into equal size of tensor apply vectorization technics like one-hot-encode

# %% [markdown]
# Listing 3.2 Encoding the integer sequences into a binary matrix

# %%
import numpy as np
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
display(x_train[1])
print(len(x_train[0]))
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])
# 10000

# %% [markdown]
# You should also vectorize your labels, which is straightforward:

# %%
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %%
y_train[0]
# Out:
# 1.0

# %% [markdown]
# 3.4.3 Building your network

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %% [markdown]
# compilation steps
#
# Loss function (binary_crossentropy,mean_squared_error) but binary_crossentropy is best

# %% [markdown]
# Listing 3.4 Compiling the model

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# 3.4.4 Validating your approach

# %%
x_val = x_train[:10000] # inputting 10000 data for validation
partial_x_train = x_train[10000:] # inputting remaining 10000 data for training

# %%
y_val = y_train[:10000] # inputting 10000 data for validation
partial_y_train = y_train[10000:] # inputting remaining 10000 data for training

# %% [markdown]
# Listing 3.8 Training your model

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])

history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=128,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 118/118 [==============================] - 2s 12ms/step - loss: 0.4217 - acc: 0.8398 - val_loss: 0.3085 - val_acc: 0.8756
# Epoch 2/20
# 118/118 [==============================] - 1s 10ms/step - loss: 0.2193 - acc: 0.9205 - val_loss: 0.2920 - val_acc: 0.8834
# Epoch 3/20
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1584 - acc: 0.9429 - val_loss: 0.3128 - val_acc: 0.8805
# Epoch 4/20
# 118/118 [==============================] - 1s 7ms/step - loss: 0.1207 - acc: 0.9574 - val_loss: 0.3348 - val_acc: 0.8809
# Epoch 5/20
# 118/118 [==============================] - 1s 6ms/step - loss: 0.0939 - acc: 0.9685 - val_loss: 0.3655 - val_acc: 0.8782
# Epoch 6/20
# 118/118 [==============================] - 1s 6ms/step - loss: 0.0710 - acc: 0.9757 - val_loss: 0.4307 - val_acc: 0.8721
# Epoch 7/20
# 118/118 [==============================] - 1s 7ms/step - loss: 0.0505 - acc: 0.9838 - val_loss: 0.4862 - val_acc: 0.8720
# Epoch 8/20
# ...

# %%
# This is dictionary showing matrix
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %% [markdown]
# Listing 3.9 Plotting the training and validation loss

# %%
import matplotlib.pyplot as plt
history_dict = history.history

loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = np.arange(1, len(history_dict["acc"]) + 1)
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# Listing 3.10 Plotting the training and validation accuracy

# %%
plt.clf()
acc_values = history_dict['acc']
val_acc_values = history_dict['val_acc']
plt.plot(epochs, history_dict["acc"], 'bo', label='Training acc')
plt.plot(epochs, history_dict["val_acc"], 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Four epoch will be enough

# %% [markdown]
# Listing 3.11 Retraining a model from scratch

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=4, batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/4
# 49/49 [==============================] - 1s 14ms/step - loss: 0.4488 - accuracy: 0.8180
# Epoch 2/4
# 49/49 [==============================] - 1s 13ms/step - loss: 0.2564 - accuracy: 0.9098
# Epoch 3/4
# 49/49 [==============================] - 1s 14ms/step - loss: 0.2023 - accuracy: 0.9279
# Epoch 4/4
# ...
# 782/782 [==============================] - 1s 1ms/step - loss: 0.2977 - accuracy: 0.8824

# %%
results
# Out:
# [0.2977488934993744, 0.8823999762535095]

# %% [markdown]
# 3.4.5 Using a trained network to generate predictions on new data

# %%
model.predict(x_test)
# Out:
# 782/782 [==============================] - 1s 1ms/step
# array([[0.23655671],
#        [0.999949  ],
#        [0.95474076],
#        ...,
#        [0.16623051],
#        [0.09912246],
#        [0.7289967 ]], dtype=float32)

# %% [markdown]
# 3.4.6 Further experiments
# The following experiments will help convince you that the architecture choices you’ve made are all fairly reasonable, although there’s still room for improvement:
#
# You used two hidden layers. Try using one or three hidden layers, and see how
# doing so affects validation and test accuracy.
#
# Try using layers with more hidden units or fewer hidden units: 32 units, 64 units,
# and so on.
#
# Try using the mse loss function instead of binary_crossentropy.
# Try using the tanh activation (an activation that was popular in the early days of
# neural networks) instead of relu.
